# %%
"""
Author: Valentina Matos (Johns Hopkins - Wirtz/Kiemen Lab)
Date: May 29, 2024
"""
import os
import tensorflow as tf
import deeplabv3plus
from deeplabv3plus.train import Trainer

from tensorflow import keras
from deeplabv3plus.model.deeplabv3_plus import DeeplabV3Plus
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D, MaxPooling2D, UpSampling2D, Concatenate
from tensorflow.keras.callbacks import LearningRateScheduler, EarlyStopping
from tensorflow.keras.optimizers import Adam
import pickle

# %%
import subprocess
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))

try:
    output = subprocess.check_output(['nvidia-smi', '--query-gpu=gpu_name', '--format=csv,noheader'])
    gpu_name = output.decode('utf-8').strip()
    print(f"GPU Name: {gpu_name}")
    tf.config.set_visible_devices([], 'GPU')  # Use the first available GPU
except (subprocess.CalledProcessError, FileNotFoundError):
    print("Unable to retrieve GPU information")
# Out:
# Num GPUs Available:  1
# GPU Name: NVIDIA GeForce RTX 3090

# %%
# Inputs
pthDL = r'\\10.99.68.52\Kiemendata\Valentina Matos\coda to python\test model\model test tiles'

# %%
# Load variables from pickle file
with open(os.path.join(pthDL, 'net.pkl'), 'rb') as f:
    data = pickle.load(f)
    sxy, classNames, nm = data['sxy'], data['classNames'], data['nm']

if 'net' in data:
    raise ValueError(f"A network has already been trained for model {nm}. Choose a new model name to retrain.")
else:
    # rest of the code here
    pass  # --delete pass when the rest of the code is placed below the else statement

# %%
# Paths to training and validation datasets:
classes = list(range(1, len(classNames)))
nmim = 'im'
nmlabel = 'label'

pthTrain = os.path.join(pthDL, 'training')
pthVal = os.path.join(pthDL, 'validation')

Train_HE = os.path.join(pthTrain, nmim)
Train_label = os.path.join(pthTrain, nmlabel)

Validation_HE = os.path.join(pthVal, nmim)
Validation_label = os.path.join(pthVal, nmlabel)

# %%
#ResNet50 model pre-trained on ImageNet
input_size = (1000, 1000, 3)  # Image dimensions
# base_model = ResNet50(weights='imagenet', include_top=False, input_shape=input_size)

model = DeepLabV3Plus(backbone='resnet50', num_classes=20)
input_shape = (1, 512, 512, 3)
input_tensor = tf.random.normal(input_shape)
result = model(input_tensor)  # build model by one forward pass
model.summary()

# %%
# Print layer names and output shapes
for layer in base_model.layers:
    print(f"{layer.name}: {layer.output_shape}")
# Out:
# input_19: [(None, 1000, 1000, 3)]
# conv1_pad: (None, 1006, 1006, 3)
# conv1_conv: (None, 500, 500, 64)
# conv1_bn: (None, 500, 500, 64)
# conv1_relu: (None, 500, 500, 64)
# pool1_pad: (None, 502, 502, 64)
# pool1_pool: (None, 250, 250, 64)
# conv2_block1_1_conv: (None, 250, 250, 64)
# conv2_block1_1_bn: (None, 250, 250, 64)
# conv2_block1_1_relu: (None, 250, 250, 64)
# conv2_block1_2_conv: (None, 250, 250, 64)
# conv2_block1_2_bn: (None, 250, 250, 64)
# conv2_block1_2_relu: (None, 250, 250, 64)
# conv2_block1_0_conv: (None, 250, 250, 256)
# conv2_block1_3_conv: (None, 250, 250, 256)
# conv2_block1_0_bn: (None, 250, 250, 256)
# conv2_block1_3_bn: (None, 250, 250, 256)
# conv2_block1_add: (None, 250, 250, 256)
# conv2_block1_out: (None, 250, 250, 256)
# conv2_block2_1_conv: (None, 250, 250, 64)
# conv2_block2_1_bn: (None, 250, 250, 64)
# conv2_block2_1_relu: (None, 250, 250, 64)
# conv2_block2_2_conv: (None, 250, 250, 64)
# conv2_block2_2_bn: (None, 250, 250, 64)
# conv2_block2_2_relu: (None, 250, 250, 64)
# conv2_block2_3_conv: (None, 250, 250, 256)
# conv2_block2_3_bn: (None, 250, 250, 256)
# conv2_block2_add: (None, 250, 250, 256)
# conv2_block2_out: (None, 250, 250, 256)
# conv2_block3_1_conv: (None, 250, 250, 64)
# conv2_block3_1_bn: (None, 250, 250, 64)
# conv2_block3_1_relu: (None, 250, 250, 64)
# conv2_block3_2_conv: (None, 250, 250, 64)
# conv2_block3_2_bn: (None, 250, 250, 64)
# conv2_block3_2_relu: (None, 250, 250, 64)
# conv2_block3_3_conv: (None, 250, 250, 256)
# conv2_block3_3_bn: (None, 250, 250, 256)
# conv2_block3_add: (None, 250, 250, 256)
# conv2_block3_out: (None, 250, 250, 256)
# conv3_block1_1_conv: (None, 125, 125, 128)
# conv3_block1_1_bn: (None, 125, 125, 128)
# conv3_block1_1_relu: (None, 125, 125, 128)
# conv3_block1_2_conv: (None, 125, 125, 128)
# conv3_block1_2_bn: (None, 125, 125, 128)
# conv3_block1_2_relu: (None, 125, 125, 128)
# conv3_block1_0_conv: (None, 125, 125, 512)
# conv3_block1_3_conv: (None, 125, 125, 512)
# conv3_block1_0_bn: (None, 125, 125, 512)
# conv3_block1_3_bn: (None, 125, 125, 512)
# conv3_block1_add: (None, 125, 125, 512)
# conv3_block1_out: (None, 125, 125, 512)
# conv3_block2_1_conv: (None, 125, 125, 128)
# conv3_block2_1_bn: (None, 125, 125, 128)
# conv3_block2_1_relu: (None, 125, 125, 128)
# conv3_block2_2_conv: (None, 125, 125, 128)
# conv3_block2_2_bn: (None, 125, 125, 128)
# conv3_block2_2_relu: (None, 125, 125, 128)
# conv3_block2_3_conv: (None, 125, 125, 512)
# conv3_block2_3_bn: (None, 125, 125, 512)
# conv3_block2_add: (None, 125, 125, 512)
# conv3_block2_out: (None, 125, 125, 512)
# conv3_block3_1_conv: (None, 125, 125, 128)
# conv3_block3_1_bn: (None, 125, 125, 128)
# conv3_block3_1_relu: (None, 125, 125, 128)
# conv3_block3_2_conv: (None, 125, 125, 128)
# conv3_block3_2_bn: (None, 125, 125, 128)
# conv3_block3_2_relu: (None, 125, 125, 128)
# conv3_block3_3_conv: (None, 125, 125, 512)
# conv3_block3_3_bn: (None, 125, 125, 512)
# conv3_block3_add: (None, 125, 125, 512)
# conv3_block3_out: (None, 125, 125, 512)
# conv3_block4_1_conv: (None, 125, 125, 128)
# conv3_block4_1_bn: (None, 125, 125, 128)
# conv3_block4_1_relu: (None, 125, 125, 128)
# conv3_block4_2_conv: (None, 125, 125, 128)
# conv3_block4_2_bn: (None, 125, 125, 128)
# conv3_block4_2_relu: (None, 125, 125, 128)
# conv3_block4_3_conv: (None, 125, 125, 512)
# conv3_block4_3_bn: (None, 125, 125, 512)
# conv3_block4_add: (None, 125, 125, 512)
# conv3_block4_out: (None, 125, 125, 512)
# conv4_block1_1_conv: (None, 63, 63, 256)
# conv4_block1_1_bn: (None, 63, 63, 256)
# conv4_block1_1_relu: (None, 63, 63, 256)
# conv4_block1_2_conv: (None, 63, 63, 256)
# conv4_block1_2_bn: (None, 63, 63, 256)
# conv4_block1_2_relu: (None, 63, 63, 256)
# conv4_block1_0_conv: (None, 63, 63, 1024)
# conv4_block1_3_conv: (None, 63, 63, 1024)
# conv4_block1_0_bn: (None, 63, 63, 1024)
# conv4_block1_3_bn: (None, 63, 63, 1024)
# conv4_block1_add: (None, 63, 63, 1024)
# conv4_block1_out: (None, 63, 63, 1024)
# conv4_block2_1_conv: (None, 63, 63, 256)
# conv4_block2_1_bn: (None, 63, 63, 256)
# conv4_block2_1_relu: (None, 63, 63, 256)
# conv4_block2_2_conv: (None, 63, 63, 256)
# conv4_block2_2_bn: (None, 63, 63, 256)
# conv4_block2_2_relu: (None, 63, 63, 256)
# conv4_block2_3_conv: (None, 63, 63, 1024)
# conv4_block2_3_bn: (None, 63, 63, 1024)
# conv4_block2_add: (None, 63, 63, 1024)
# conv4_block2_out: (None, 63, 63, 1024)
# conv4_block3_1_conv: (None, 63, 63, 256)
# conv4_block3_1_bn: (None, 63, 63, 256)
# conv4_block3_1_relu: (None, 63, 63, 256)
# conv4_block3_2_conv: (None, 63, 63, 256)
# conv4_block3_2_bn: (None, 63, 63, 256)
# conv4_block3_2_relu: (None, 63, 63, 256)
# conv4_block3_3_conv: (None, 63, 63, 1024)
# conv4_block3_3_bn: (None, 63, 63, 1024)
# conv4_block3_add: (None, 63, 63, 1024)
# conv4_block3_out: (None, 63, 63, 1024)
# conv4_block4_1_conv: (None, 63, 63, 256)
# conv4_block4_1_bn: (None, 63, 63, 256)
# conv4_block4_1_relu: (None, 63, 63, 256)
# conv4_block4_2_conv: (None, 63, 63, 256)
# conv4_block4_2_bn: (None, 63, 63, 256)
# conv4_block4_2_relu: (None, 63, 63, 256)
# conv4_block4_3_conv: (None, 63, 63, 1024)
# conv4_block4_3_bn: (None, 63, 63, 1024)
# conv4_block4_add: (None, 63, 63, 1024)
# conv4_block4_out: (None, 63, 63, 1024)
# conv4_block5_1_conv: (None, 63, 63, 256)
# conv4_block5_1_bn: (None, 63, 63, 256)
# conv4_block5_1_relu: (None, 63, 63, 256)
# conv4_block5_2_conv: (None, 63, 63, 256)
# conv4_block5_2_bn: (None, 63, 63, 256)
# conv4_block5_2_relu: (None, 63, 63, 256)
# conv4_block5_3_conv: (None, 63, 63, 1024)
# conv4_block5_3_bn: (None, 63, 63, 1024)
# conv4_block5_add: (None, 63, 63, 1024)
# conv4_block5_out: (None, 63, 63, 1024)
# conv4_block6_1_conv: (None, 63, 63, 256)
# conv4_block6_1_bn: (None, 63, 63, 256)
# conv4_block6_1_relu: (None, 63, 63, 256)
# conv4_block6_2_conv: (None, 63, 63, 256)
# conv4_block6_2_bn: (None, 63, 63, 256)
# conv4_block6_2_relu: (None, 63, 63, 256)
# conv4_block6_3_conv: (None, 63, 63, 1024)
# conv4_block6_3_bn: (None, 63, 63, 1024)
# conv4_block6_add: (None, 63, 63, 1024)
# conv4_block6_out: (None, 63, 63, 1024)
# conv5_block1_1_conv: (None, 32, 32, 512)
# conv5_block1_1_bn: (None, 32, 32, 512)
# conv5_block1_1_relu: (None, 32, 32, 512)
# conv5_block1_2_conv: (None, 32, 32, 512)
# conv5_block1_2_bn: (None, 32, 32, 512)
# conv5_block1_2_relu: (None, 32, 32, 512)
# conv5_block1_0_conv: (None, 32, 32, 2048)
# conv5_block1_3_conv: (None, 32, 32, 2048)
# conv5_block1_0_bn: (None, 32, 32, 2048)
# conv5_block1_3_bn: (None, 32, 32, 2048)
# conv5_block1_add: (None, 32, 32, 2048)
# conv5_block1_out: (None, 32, 32, 2048)
# conv5_block2_1_conv: (None, 32, 32, 512)
# conv5_block2_1_bn: (None, 32, 32, 512)
# conv5_block2_1_relu: (None, 32, 32, 512)
# conv5_block2_2_conv: (None, 32, 32, 512)
# conv5_block2_2_bn: (None, 32, 32, 512)
# conv5_block2_2_relu: (None, 32, 32, 512)
# conv5_block2_3_conv: (None, 32, 32, 2048)
# conv5_block2_3_bn: (None, 32, 32, 2048)
# conv5_block2_add: (None, 32, 32, 2048)
# conv5_block2_out: (None, 32, 32, 2048)
# conv5_block3_1_conv: (None, 32, 32, 512)
# conv5_block3_1_bn: (None, 32, 32, 512)
# conv5_block3_1_relu: (None, 32, 32, 512)
# conv5_block3_2_conv: (None, 32, 32, 512)
# conv5_block3_2_bn: (None, 32, 32, 512)
# conv5_block3_2_relu: (None, 32, 32, 512)
# conv5_block3_3_conv: (None, 32, 32, 2048)
# conv5_block3_3_bn: (None, 32, 32, 2048)
# conv5_block3_add: (None, 32, 32, 2048)
# conv5_block3_out: (None, 32, 32, 2048)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, Conv2DTranspose, Concatenate, Cropping2D
from tensorflow.keras.models import Model

# Load the ResNet50 model with pre-trained weights
base_model = tf.keras.applications.ResNet50(weights='imagenet', include_top=False, input_shape=(1000, 1000, 3))

# Freeze the base model
for layer in base_model.layers:
    layer.trainable = False

# Decoder path with transposed convolutions
x = base_model.output  # Start with the output of the ResNet50
x = Conv2D(512, (3, 3), activation='relu', padding='same')(x)
x = Conv2D(512, (3, 3), activation='relu', padding='same')(x)
x = Conv2DTranspose(512, (4, 4), strides=(2, 2), padding='same')(x)

# Ensure matching dimensions before concatenation with 'conv4_block6_out'
conv4_block6_out = base_model.get_layer('conv4_block6_out').output
x = Cropping2D(((1, 0), (1, 0)))(x)  # Adjust dimensions to match
x = Concatenate()([x, conv4_block6_out])

x = Conv2D(256, (3, 3), activation='relu', padding='same')(x)
x = Conv2D(256, (3, 3), activation='relu', padding='same')(x)
x = Conv2DTranspose(256, (4, 4), strides=(2, 2), padding='same')(x)

# Ensure matching dimensions before concatenation with 'conv3_block4_out'
conv3_block4_out = base_model.get_layer('conv3_block4_out').output
x = Cropping2D(((1, 0), (1, 0)))(x)  # Adjust dimensions to match
x = Concatenate()([x, conv3_block4_out])

x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = Conv2DTranspose(128, (4, 4), strides=(2, 2), padding='same')(x)

# Ensure matching dimensions before concatenation with 'conv2_block3_out'
conv2_block3_out = base_model.get_layer('conv2_block3_out').output
x = Concatenate()([x, conv2_block3_out])

x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = Conv2DTranspose(64, (4, 4), strides=(2, 2), padding='same')(x)

# Ensure matching dimensions before concatenation with 'conv1_conv'
conv1_conv = base_model.get_layer('conv1_conv').output
x = Concatenate()([x, conv1_conv])

x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)

# Final convolutional layer for class prediction
output = Conv2D(len(classNames), (1, 1), activation='softmax')(x)

# %%
# Create the model
model = Model(inputs=base_model.input, outputs=output)

# Print model summary
model.summary()
# Out:
# Model: "model_8"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_20 (InputLayer)          [(None, 1000, 1000,  0           []
#                                  3)]
#
#  conv1_pad (ZeroPadding2D)      (None, 1006, 1006,   0           ['input_20[0][0]']
#                                 3)
#
#  conv1_conv (Conv2D)            (None, 500, 500, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  conv1_bn (BatchNormalization)  (None, 500, 500, 64  256         ['conv1_conv[0][0]']
#                                 )
#
#  conv1_relu (Activation)        (None, 500, 500, 64  0           ['conv1_bn[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 502, 502, 64  0           ['conv1_relu[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 250, 250, 64  0           ['pool1_pad[0][0]']
#                                 )
#
#  conv2_block1_1_conv (Conv2D)   (None, 250, 250, 64  4160        ['pool1_pool[0][0]']
#                                 )
#
#  conv2_block1_1_bn (BatchNormal  (None, 250, 250, 64  256        ['conv2_block1_1_conv[0][0]']
#  ization)                       )
#
#  conv2_block1_1_relu (Activatio  (None, 250, 250, 64  0          ['conv2_block1_1_bn[0][0]']
#  n)                             )
#
#  conv2_block1_2_conv (Conv2D)   (None, 250, 250, 64  36928       ['conv2_block1_1_relu[0][0]']
#                                 )
#
#  conv2_block1_2_bn (BatchNormal  (None, 250, 250, 64  256        ['conv2_block1_2_conv[0][0]']
#  ization)                       )
#
#  conv2_block1_2_relu (Activatio  (None, 250, 250, 64  0          ['conv2_block1_2_bn[0][0]']
#  n)                             )
#
#  conv2_block1_0_conv (Conv2D)   (None, 250, 250, 25  16640       ['pool1_pool[0][0]']
#                                 6)
#
#  conv2_block1_3_conv (Conv2D)   (None, 250, 250, 25  16640       ['conv2_block1_2_relu[0][0]']
#                                 6)
#
#  conv2_block1_0_bn (BatchNormal  (None, 250, 250, 25  1024       ['conv2_block1_0_conv[0][0]']
#  ization)                       6)
#
#  conv2_block1_3_bn (BatchNormal  (None, 250, 250, 25  1024       ['conv2_block1_3_conv[0][0]']
#  ization)                       6)
#
#  conv2_block1_add (Add)         (None, 250, 250, 25  0           ['conv2_block1_0_bn[0][0]',
#                                 6)                                'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, 250, 250, 25  0           ['conv2_block1_add[0][0]']
#                                 6)
#
#  conv2_block2_1_conv (Conv2D)   (None, 250, 250, 64  16448       ['conv2_block1_out[0][0]']
#                                 )
#
#  conv2_block2_1_bn (BatchNormal  (None, 250, 250, 64  256        ['conv2_block2_1_conv[0][0]']
#  ization)                       )
#
#  conv2_block2_1_relu (Activatio  (None, 250, 250, 64  0          ['conv2_block2_1_bn[0][0]']
#  n)                             )
#
#  conv2_block2_2_conv (Conv2D)   (None, 250, 250, 64  36928       ['conv2_block2_1_relu[0][0]']
#                                 )
#
#  conv2_block2_2_bn (BatchNormal  (None, 250, 250, 64  256        ['conv2_block2_2_conv[0][0]']
#  ization)                       )
#
#  conv2_block2_2_relu (Activatio  (None, 250, 250, 64  0          ['conv2_block2_2_bn[0][0]']
#  n)                             )
#
#  conv2_block2_3_conv (Conv2D)   (None, 250, 250, 25  16640       ['conv2_block2_2_relu[0][0]']
#                                 6)
#
#  conv2_block2_3_bn (BatchNormal  (None, 250, 250, 25  1024       ['conv2_block2_3_conv[0][0]']
#  ization)                       6)
#
#  conv2_block2_add (Add)         (None, 250, 250, 25  0           ['conv2_block1_out[0][0]',
#                                 6)                                'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, 250, 250, 25  0           ['conv2_block2_add[0][0]']
#                                 6)
#
#  conv2_block3_1_conv (Conv2D)   (None, 250, 250, 64  16448       ['conv2_block2_out[0][0]']
#                                 )
#
#  conv2_block3_1_bn (BatchNormal  (None, 250, 250, 64  256        ['conv2_block3_1_conv[0][0]']
#  ization)                       )
#
#  conv2_block3_1_relu (Activatio  (None, 250, 250, 64  0          ['conv2_block3_1_bn[0][0]']
#  n)                             )
#
#  conv2_block3_2_conv (Conv2D)   (None, 250, 250, 64  36928       ['conv2_block3_1_relu[0][0]']
#                                 )
#
#  conv2_block3_2_bn (BatchNormal  (None, 250, 250, 64  256        ['conv2_block3_2_conv[0][0]']
#  ization)                       )
#
#  conv2_block3_2_relu (Activatio  (None, 250, 250, 64  0          ['conv2_block3_2_bn[0][0]']
#  n)                             )
#
#  conv2_block3_3_conv (Conv2D)   (None, 250, 250, 25  16640       ['conv2_block3_2_relu[0][0]']
#                                 6)
#
#  conv2_block3_3_bn (BatchNormal  (None, 250, 250, 25  1024       ['conv2_block3_3_conv[0][0]']
#  ization)                       6)
#
#  conv2_block3_add (Add)         (None, 250, 250, 25  0           ['conv2_block2_out[0][0]',
#                                 6)                                'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, 250, 250, 25  0           ['conv2_block3_add[0][0]']
#                                 6)
#
#  conv3_block1_1_conv (Conv2D)   (None, 125, 125, 12  32896       ['conv2_block3_out[0][0]']
#                                 8)
#
#  conv3_block1_1_bn (BatchNormal  (None, 125, 125, 12  512        ['conv3_block1_1_conv[0][0]']
#  ization)                       8)
#
#  conv3_block1_1_relu (Activatio  (None, 125, 125, 12  0          ['conv3_block1_1_bn[0][0]']
#  n)                             8)
#
#  conv3_block1_2_conv (Conv2D)   (None, 125, 125, 12  147584      ['conv3_block1_1_relu[0][0]']
#                                 8)
#
#  conv3_block1_2_bn (BatchNormal  (None, 125, 125, 12  512        ['conv3_block1_2_conv[0][0]']
#  ization)                       8)
#
#  conv3_block1_2_relu (Activatio  (None, 125, 125, 12  0          ['conv3_block1_2_bn[0][0]']
#  n)                             8)
#
#  conv3_block1_0_conv (Conv2D)   (None, 125, 125, 51  131584      ['conv2_block3_out[0][0]']
#                                 2)
#
#  conv3_block1_3_conv (Conv2D)   (None, 125, 125, 51  66048       ['conv3_block1_2_relu[0][0]']
#                                 2)
#
#  conv3_block1_0_bn (BatchNormal  (None, 125, 125, 51  2048       ['conv3_block1_0_conv[0][0]']
#  ization)                       2)
#
#  conv3_block1_3_bn (BatchNormal  (None, 125, 125, 51  2048       ['conv3_block1_3_conv[0][0]']
#  ization)                       2)
#
#  conv3_block1_add (Add)         (None, 125, 125, 51  0           ['conv3_block1_0_bn[0][0]',
#                                 2)                                'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, 125, 125, 51  0           ['conv3_block1_add[0][0]']
#                                 2)
#
#  conv3_block2_1_conv (Conv2D)   (None, 125, 125, 12  65664       ['conv3_block1_out[0][0]']
#                                 8)
#
#  conv3_block2_1_bn (BatchNormal  (None, 125, 125, 12  512        ['conv3_block2_1_conv[0][0]']
#  ization)                       8)
#
#  conv3_block2_1_relu (Activatio  (None, 125, 125, 12  0          ['conv3_block2_1_bn[0][0]']
#  n)                             8)
#
#  conv3_block2_2_conv (Conv2D)   (None, 125, 125, 12  147584      ['conv3_block2_1_relu[0][0]']
#                                 8)
#
#  conv3_block2_2_bn (BatchNormal  (None, 125, 125, 12  512        ['conv3_block2_2_conv[0][0]']
#  ization)                       8)
#
#  conv3_block2_2_relu (Activatio  (None, 125, 125, 12  0          ['conv3_block2_2_bn[0][0]']
#  n)                             8)
#
#  conv3_block2_3_conv (Conv2D)   (None, 125, 125, 51  66048       ['conv3_block2_2_relu[0][0]']
#                                 2)
#
#  conv3_block2_3_bn (BatchNormal  (None, 125, 125, 51  2048       ['conv3_block2_3_conv[0][0]']
#  ization)                       2)
#
#  conv3_block2_add (Add)         (None, 125, 125, 51  0           ['conv3_block1_out[0][0]',
#                                 2)                                'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, 125, 125, 51  0           ['conv3_block2_add[0][0]']
#                                 2)
#
#  conv3_block3_1_conv (Conv2D)   (None, 125, 125, 12  65664       ['conv3_block2_out[0][0]']
#                                 8)
#
#  conv3_block3_1_bn (BatchNormal  (None, 125, 125, 12  512        ['conv3_block3_1_conv[0][0]']
#  ization)                       8)
#
#  conv3_block3_1_relu (Activatio  (None, 125, 125, 12  0          ['conv3_block3_1_bn[0][0]']
#  n)                             8)
#
#  conv3_block3_2_conv (Conv2D)   (None, 125, 125, 12  147584      ['conv3_block3_1_relu[0][0]']
#                                 8)
#
#  conv3_block3_2_bn (BatchNormal  (None, 125, 125, 12  512        ['conv3_block3_2_conv[0][0]']
#  ization)                       8)
#
#  conv3_block3_2_relu (Activatio  (None, 125, 125, 12  0          ['conv3_block3_2_bn[0][0]']
#  n)                             8)
#
#  conv3_block3_3_conv (Conv2D)   (None, 125, 125, 51  66048       ['conv3_block3_2_relu[0][0]']
#                                 2)
#
#  conv3_block3_3_bn (BatchNormal  (None, 125, 125, 51  2048       ['conv3_block3_3_conv[0][0]']
#  ization)                       2)
#
#  conv3_block3_add (Add)         (None, 125, 125, 51  0           ['conv3_block2_out[0][0]',
#                                 2)                                'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activation)  (None, 125, 125, 51  0           ['conv3_block3_add[0][0]']
#                                 2)
#
#  conv3_block4_1_conv (Conv2D)   (None, 125, 125, 12  65664       ['conv3_block3_out[0][0]']
#                                 8)
#
#  conv3_block4_1_bn (BatchNormal  (None, 125, 125, 12  512        ['conv3_block4_1_conv[0][0]']
#  ization)                       8)
#
#  conv3_block4_1_relu (Activatio  (None, 125, 125, 12  0          ['conv3_block4_1_bn[0][0]']
#  n)                             8)
#
#  conv3_block4_2_conv (Conv2D)   (None, 125, 125, 12  147584      ['conv3_block4_1_relu[0][0]']
#                                 8)
#
#  conv3_block4_2_bn (BatchNormal  (None, 125, 125, 12  512        ['conv3_block4_2_conv[0][0]']
#  ization)                       8)
#
#  conv3_block4_2_relu (Activatio  (None, 125, 125, 12  0          ['conv3_block4_2_bn[0][0]']
#  n)                             8)
#
#  conv3_block4_3_conv (Conv2D)   (None, 125, 125, 51  66048       ['conv3_block4_2_relu[0][0]']
#                                 2)
#
#  conv3_block4_3_bn (BatchNormal  (None, 125, 125, 51  2048       ['conv3_block4_3_conv[0][0]']
#  ization)                       2)
#
#  conv3_block4_add (Add)         (None, 125, 125, 51  0           ['conv3_block3_out[0][0]',
#                                 2)                                'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activation)  (None, 125, 125, 51  0           ['conv3_block4_add[0][0]']
#                                 2)
#
#  conv4_block1_1_conv (Conv2D)   (None, 63, 63, 256)  131328      ['conv3_block4_out[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 63, 63, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 63, 63, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 63, 63, 256)  590080      ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 63, 63, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 63, 63, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 63, 63, 1024  525312      ['conv3_block4_out[0][0]']
#                                 )
#
#  conv4_block1_3_conv (Conv2D)   (None, 63, 63, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_0_bn (BatchNormal  (None, 63, 63, 1024  4096       ['conv4_block1_0_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_3_bn (BatchNormal  (None, 63, 63, 1024  4096       ['conv4_block1_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_add (Add)         (None, 63, 63, 1024  0           ['conv4_block1_0_bn[0][0]',
#                                 )                                 'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activation)  (None, 63, 63, 1024  0           ['conv4_block1_add[0][0]']
#                                 )
#
#  conv4_block2_1_conv (Conv2D)   (None, 63, 63, 256)  262400      ['conv4_block1_out[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 63, 63, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 63, 63, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 63, 63, 256)  590080      ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 63, 63, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 63, 63, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 63, 63, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_3_bn (BatchNormal  (None, 63, 63, 1024  4096       ['conv4_block2_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block2_add (Add)         (None, 63, 63, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activation)  (None, 63, 63, 1024  0           ['conv4_block2_add[0][0]']
#                                 )
#
#  conv4_block3_1_conv (Conv2D)   (None, 63, 63, 256)  262400      ['conv4_block2_out[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 63, 63, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 63, 63, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 63, 63, 256)  590080      ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 63, 63, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 63, 63, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 63, 63, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_3_bn (BatchNormal  (None, 63, 63, 1024  4096       ['conv4_block3_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block3_add (Add)         (None, 63, 63, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activation)  (None, 63, 63, 1024  0           ['conv4_block3_add[0][0]']
#                                 )
#
#  conv4_block4_1_conv (Conv2D)   (None, 63, 63, 256)  262400      ['conv4_block3_out[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 63, 63, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 63, 63, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 63, 63, 256)  590080      ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 63, 63, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 63, 63, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 63, 63, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_3_bn (BatchNormal  (None, 63, 63, 1024  4096       ['conv4_block4_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block4_add (Add)         (None, 63, 63, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activation)  (None, 63, 63, 1024  0           ['conv4_block4_add[0][0]']
#                                 )
#
#  conv4_block5_1_conv (Conv2D)   (None, 63, 63, 256)  262400      ['conv4_block4_out[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 63, 63, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 63, 63, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 63, 63, 256)  590080      ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 63, 63, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 63, 63, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 63, 63, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_3_bn (BatchNormal  (None, 63, 63, 1024  4096       ['conv4_block5_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block5_add (Add)         (None, 63, 63, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activation)  (None, 63, 63, 1024  0           ['conv4_block5_add[0][0]']
#                                 )
#
#  conv4_block6_1_conv (Conv2D)   (None, 63, 63, 256)  262400      ['conv4_block5_out[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 63, 63, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 63, 63, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_conv (Conv2D)   (None, 63, 63, 256)  590080      ['conv4_block6_1_relu[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 63, 63, 256)  1024       ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 63, 63, 256)  0          ['conv4_block6_2_bn[0][0]']
#  n)
#
#  conv4_block6_3_conv (Conv2D)   (None, 63, 63, 1024  263168      ['conv4_block6_2_relu[0][0]']
#                                 )
#
#  conv4_block6_3_bn (BatchNormal  (None, 63, 63, 1024  4096       ['conv4_block6_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block6_add (Add)         (None, 63, 63, 1024  0           ['conv4_block5_out[0][0]',
#                                 )                                 'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activation)  (None, 63, 63, 1024  0           ['conv4_block6_add[0][0]']
#                                 )
#
#  conv5_block1_1_conv (Conv2D)   (None, 32, 32, 512)  524800      ['conv4_block6_out[0][0]']
#
#  conv5_block1_1_bn (BatchNormal  (None, 32, 32, 512)  2048       ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 32, 32, 512)  0          ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_conv (Conv2D)   (None, 32, 32, 512)  2359808     ['conv5_block1_1_relu[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 32, 32, 512)  2048       ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 32, 32, 512)  0          ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 32, 32, 2048  2099200     ['conv4_block6_out[0][0]']
#                                 )
#
#  conv5_block1_3_conv (Conv2D)   (None, 32, 32, 2048  1050624     ['conv5_block1_2_relu[0][0]']
#                                 )
#
#  conv5_block1_0_bn (BatchNormal  (None, 32, 32, 2048  8192       ['conv5_block1_0_conv[0][0]']
#  ization)                       )
#
#  conv5_block1_3_bn (BatchNormal  (None, 32, 32, 2048  8192       ['conv5_block1_3_conv[0][0]']
#  ization)                       )
#
#  conv5_block1_add (Add)         (None, 32, 32, 2048  0           ['conv5_block1_0_bn[0][0]',
#                                 )                                 'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activation)  (None, 32, 32, 2048  0           ['conv5_block1_add[0][0]']
#                                 )
#
#  conv5_block2_1_conv (Conv2D)   (None, 32, 32, 512)  1049088     ['conv5_block1_out[0][0]']
#
#  conv5_block2_1_bn (BatchNormal  (None, 32, 32, 512)  2048       ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 32, 32, 512)  0          ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_conv (Conv2D)   (None, 32, 32, 512)  2359808     ['conv5_block2_1_relu[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 32, 32, 512)  2048       ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 32, 32, 512)  0          ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 32, 32, 2048  1050624     ['conv5_block2_2_relu[0][0]']
#                                 )
#
#  conv5_block2_3_bn (BatchNormal  (None, 32, 32, 2048  8192       ['conv5_block2_3_conv[0][0]']
#  ization)                       )
#
#  conv5_block2_add (Add)         (None, 32, 32, 2048  0           ['conv5_block1_out[0][0]',
#                                 )                                 'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activation)  (None, 32, 32, 2048  0           ['conv5_block2_add[0][0]']
#                                 )
#
#  conv5_block3_1_conv (Conv2D)   (None, 32, 32, 512)  1049088     ['conv5_block2_out[0][0]']
#
#  conv5_block3_1_bn (BatchNormal  (None, 32, 32, 512)  2048       ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 32, 32, 512)  0          ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_conv (Conv2D)   (None, 32, 32, 512)  2359808     ['conv5_block3_1_relu[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 32, 32, 512)  2048       ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 32, 32, 512)  0          ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 32, 32, 2048  1050624     ['conv5_block3_2_relu[0][0]']
#                                 )
#
#  conv5_block3_3_bn (BatchNormal  (None, 32, 32, 2048  8192       ['conv5_block3_3_conv[0][0]']
#  ization)                       )
#
#  conv5_block3_add (Add)         (None, 32, 32, 2048  0           ['conv5_block2_out[0][0]',
#                                 )                                 'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activation)  (None, 32, 32, 2048  0           ['conv5_block3_add[0][0]']
#                                 )
#
#  conv2d_128 (Conv2D)            (None, 32, 32, 512)  9437696     ['conv5_block3_out[0][0]']
#
#  conv2d_129 (Conv2D)            (None, 32, 32, 512)  2359808     ['conv2d_128[0][0]']
#
#  conv2d_transpose_24 (Conv2DTra  (None, 64, 64, 512)  4194816    ['conv2d_129[0][0]']
#  nspose)
#
#  cropping2d_26 (Cropping2D)     (None, 63, 63, 512)  0           ['conv2d_transpose_24[0][0]']
#
#  concatenate_46 (Concatenate)   (None, 63, 63, 1536  0           ['cropping2d_26[0][0]',
#                                 )                                 'conv4_block6_out[0][0]']
#
#  conv2d_130 (Conv2D)            (None, 63, 63, 256)  3539200     ['concatenate_46[0][0]']
#
#  conv2d_131 (Conv2D)            (None, 63, 63, 256)  590080      ['conv2d_130[0][0]']
#
#  conv2d_transpose_25 (Conv2DTra  (None, 126, 126, 25  1048832    ['conv2d_131[0][0]']
#  nspose)                        6)
#
#  cropping2d_27 (Cropping2D)     (None, 125, 125, 25  0           ['conv2d_transpose_25[0][0]']
#                                 6)
#
#  concatenate_47 (Concatenate)   (None, 125, 125, 76  0           ['cropping2d_27[0][0]',
#                                 8)                                'conv3_block4_out[0][0]']
#
#  conv2d_132 (Conv2D)            (None, 125, 125, 12  884864      ['concatenate_47[0][0]']
#                                 8)
#
#  conv2d_133 (Conv2D)            (None, 125, 125, 12  147584      ['conv2d_132[0][0]']
#                                 8)
#
#  conv2d_transpose_26 (Conv2DTra  (None, 250, 250, 12  262272     ['conv2d_133[0][0]']
#  nspose)                        8)
#
#  concatenate_48 (Concatenate)   (None, 250, 250, 38  0           ['conv2d_transpose_26[0][0]',
#                                 4)                                'conv2_block3_out[0][0]']
#
#  conv2d_134 (Conv2D)            (None, 250, 250, 64  221248      ['concatenate_48[0][0]']
#                                 )
#
#  conv2d_135 (Conv2D)            (None, 250, 250, 64  36928       ['conv2d_134[0][0]']
#                                 )
#
#  conv2d_transpose_27 (Conv2DTra  (None, 500, 500, 64  65600      ['conv2d_135[0][0]']
#  nspose)                        )
#
#  concatenate_49 (Concatenate)   (None, 500, 500, 12  0           ['conv2d_transpose_27[0][0]',
#                                 8)                                'conv1_conv[0][0]']
#
#  conv2d_136 (Conv2D)            (None, 500, 500, 64  73792       ['concatenate_49[0][0]']
#                                 )
#
#  conv2d_137 (Conv2D)            (None, 500, 500, 64  36928       ['conv2d_136[0][0]']
#                                 )
#
#  conv2d_138 (Conv2D)            (None, 500, 500, 12  780         ['conv2d_137[0][0]']
#                                 )
#
# ==================================================================================================
# Total params: 46,488,140
# Trainable params: 22,900,428
# Non-trainable params: 23,587,712
# __________________________________________________________________________________________________

# %%
# Fine-tune the entire model
#  sets all layers of the pre-trained ResNet50 model as trainable. By default, when using a pre-trained model, the base layers are frozen (not trainable) to preserve the learned weights. Setting layer.trainable = True for all layers allows the entire model to be fine-tuned on your specific task and dataset.
for layer in base_model.layers:
    layer.trainable = True

# %%
# Compile the model
model.compile(optimizer=Adam(learning_rate=5e-4), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
### Prepare the data generators

# ImageDataGenerator for training data with rescaling
train_datagen = ImageDataGenerator(rescale=1./255)  # Normalizes the pixel values to [0, 1]
# ImageDataGenerator for validation data with rescaling
val_datagen = ImageDataGenerator(rescale=1./255)    # Normalizes the pixel values to [0, 1]


classes = [str(cls) for cls in classes] #convert classes for string format

train_generator = train_datagen.flow_from_directory(
    Train_HE,                # Path to the training data directory containing subdirectories of images
    target_size=(1000, 1000),# Resize all images to 1000x1000 pixels
    batch_size=4,            # Number of images to be yielded from the generator per batch
    class_mode=None,         # Don't return the labels (since it's an autoencoder task or a task where labels are not needed here)
    color_mode='rgb',        # Read images in RGB mode
    classes=classes,         # List of subdirectory names to consider as valid labels
    seed=42                  # Random seed for reproducibility
)


val_generator = val_datagen.flow_from_directory(
    Validation_HE,
    target_size=(1000, 1000),
    batch_size=4,
    class_mode=None,
    color_mode='rgb',
    classes=classes,
    seed=42
)

# Generate batches of label data with real-time data augmentation.
train_label_generator = train_datagen.flow_from_directory(
    Train_label,             # Path to the directory containing training labels
    target_size=(1000, 1000),# Resize all labels to 1000x1000 pixels
    batch_size=4,            # Number of labels to be yielded from the generator per batch
    class_mode='categorical',# Return the labels as one-hot encoded arrays
    color_mode='grayscale',  # Read labels in grayscale mode
    classes=classes,         # List of subdirectory names to consider as classes
    seed=42                  # Random seed for reproducibility
)

val_label_generator = val_datagen.flow_from_directory(
    Validation_label,
    target_size=(1000, 1000),
    batch_size=4,
    class_mode='categorical',
    color_mode='grayscale',
    classes=classes,
    seed=42
)
# Out:
# Found 0 images belonging to 11 classes.
# Found 0 images belonging to 11 classes.
# Found 0 images belonging to 11 classes.
# Found 0 images belonging to 11 classes.

# %%
import os
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
import numpy as np

def custom_image_generator(directory, target_size, batch_size, color_mode, classes, seed):
    np.random.seed(seed)
    while True:
        batch_features = []
        batch_labels = []
        for _ in range(batch_size):
            # Randomly select a class
            class_name = np.random.choice(classes)
            class_dir = os.path.join(directory, class_name)
            # Randomly select an image from the class directory
            image_name = np.random.choice(os.listdir(class_dir))
            image_path = os.path.join(class_dir, image_name)
            
            # Load the image
            img = load_img(image_path, target_size=target_size, color_mode=color_mode)
            img_array = img_to_array(img) / 255.0
            
            batch_features.append(img_array)
            # One-hot encode the label
            label = np.zeros(len(classes))
            label[classes.index(class_name)] = 1
            batch_labels.append(label)
        
        yield np.array(batch_features), np.array(batch_labels)

# Convert classes to string format
class_dirs = [str(cls) for cls in classes]

# Create custom generators
train_generator = custom_image_generator(
    Train_HE, 
    target_size=(1000, 1000), 
    batch_size=4, 
    color_mode='rgb', 
    classes=class_dirs, 
    seed=42
)

val_generator = custom_image_generator(
    Validation_HE, 
    target_size=(1000, 1000), 
    batch_size=4, 
    color_mode='rgb', 
    classes=class_dirs, 
    seed=42
)

train_label_generator = custom_image_generator(
    Train_label, 
    target_size=(1000, 1000), 
    batch_size=4, 
    color_mode='grayscale', 
    classes=class_dirs, 
    seed=42
)

val_label_generator = custom_image_generator(
    Validation_label, 
    target_size=(1000, 1000), 
    batch_size=4, 
    color_mode='grayscale', 
    classes=class_dirs, 
    seed=42
)

# %%
print(Train_HE)
# Out:
# \\10.99.68.52\Kiemendata\Valentina Matos\coda to python\test model\model test tiles\training\im

# %%
# Define the learning rate schedule
def step_decay(epoch):
    initial_lr = 0.001
    drop_rate = 0.5
    epoch_drop = 5
    lrate = initial_lr * drop_rate ** (epoch // epoch_drop)
    return lrate

# Create the learning rate scheduler callback
lr_scheduler = LearningRateScheduler(step_decay)

# %%
# Create the early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=7, restore_best_weights=True)

# %%
# Train the model
history = model.fit(
    train_generator,
    train_label_generator,
    steps_per_epoch=len(train_generator),
    epochs=8,
    validation_data=(val_generator, val_label_generator),
    validation_steps=len(val_generator),
    callbacks=[lr_scheduler, early_stopping]
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[80], line 2
#       1 # Train the model
# ----> 2 history = model.fit(
#       3     train_generator,
#       4     train_label_generator,
#       5     steps_per_epoch=len(train_generator),
#       6     epochs=8,
#       7     validation_data=(val_generator, val_label_generator),
#       8     validation_steps=len(val_generator),
#       9     callbacks=[lr_scheduler, early_stopping]
#      10 )
#
# File ~\anaconda3\envs\CODA_tinaFlow\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\anaconda3\envs\CODA_tinaFlow\lib\site-packages\keras\engine\data_adapter.py:997, in KerasSequenceAdapter.__init__(self, x, y, sample_weights, shuffle, workers, use_multiprocessing, max_queue_size, model, **kwargs)
#     984 def __init__(
#     985     self,
#     986     x,
#    (...)
#     994     **kwargs
#     995 ):
#     996     if not is_none_or_empty(y):
# --> 997         raise ValueError(
#     998             "`y` argument is not supported when using "
#     999             "`keras.utils.Sequence` as input."
#    1000         )
#    1001     if not is_none_or_empty(sample_weights):
#    1002         raise ValueError(
#    1003             "`sample_weight` argument is not supported when using "
#    1004             "`keras.utils.Sequence` as input."
#    1005         )
#
# ValueError: `y` argument is not supported when using `keras.utils.Sequence` as input.

# %%
# Save the model
print('Saving model weights...')
data['net'] = model.get_weights()  # Get the model weights
data['history'] = history.history  # Get the model history

with open(os.path.join(pthDL, 'net.pkl'), 'wb') as f:
    pickle.dump(data, f)

# %%
# Load the model history from the pickle file
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

with open(os.path.join(pthDL, 'net.pkl'), 'rb') as f:
    data = pickle.load(f)
    model_history = data['history']
    
history_df = pd.DataFrame(model_history)
# Use seaborn color palette
sns.set_palette("colorblind")

# Plot loss and accuracy in a single figure
plt.figure(figsize=(12, 6))

# Plot loss
plt.subplot(1, 2, 1)
sns.lineplot(data=history_df, x=history_df.index, y='loss', label='Training Loss')
sns.lineplot(data=history_df, x=history_df.index, y='val_loss', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.grid(True)

# Plot accuracy
plt.subplot(1, 2, 2)
sns.lineplot(data=history_df, x=history_df.index, y='accuracy', label='Training Accuracy')
sns.lineplot(data=history_df, x=history_df.index, y='val_accuracy', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[17], line 2
#       1 # Load the model history from the pickle file
# ----> 2 with open(os.path.join(pthDL, 'net.pkl'), 'rb') as f:
#       3     data = pickle.load(f)
#       4     model_history = data['history']
#
# File ~\anaconda3\envs\CODA_tinaFlow\lib\site-packages\IPython\core\interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '\\\\10.99.68.52\\Kiemendata\\Valentina Matos\\coda to python\\test model\\04_19_2024\\net.pkl'

# %%
# %reset
